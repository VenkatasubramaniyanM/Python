# %%
import pandas as pd # it has multiple functions to extract the reports

# %%
dataset=pd.read_csv("Salary_Data.csv")

# %%
dataset
# Out:
#     YearsExperience  Salary
# 0               1.1   24000
# 1               2.6   35000
# 2               2.2   33000
# 3               3.5   45000
# 4              10.5   93000
# 5               4.8   53000
# 6               8.9   78000
# 7               3.4   44000
# 8               7.9   70000
# 9               1.9   28000
# 10              5.5   60000
# 11              6.7   63000
# 12              9.8   85000
# 13              2.9   39000
# 14              3.9   47000

# %%
independent=dataset[["YearsExperience"]]
independent

# %%
dependent=dataset[["Salary"]]
dependent

# %%
dependent
# Out:
#     Salary
# 0    24000
# 1    35000
# 2    33000
# 3    45000
# 4    93000
# 5    53000
# 6    78000
# 7    44000
# 8    70000
# 9    28000
# 10   60000
# 11   63000
# 12   85000
# 13   39000
# 14   47000

# %%
from sklearn.model_selection import train_test_split # from sklearn we can use some particular function as per our needs
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
weight=regressor.coef_
weight
# Out:
# array([[6972.63423651]])

# %%
bais=regressor.intercept_
bais
# Out:
# array([18757.923448])

# %%
y_pred=regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.9770342214522156

# %%
import pickle# this is for save the model
filename="Finalized_model_linear.sav"

# %%
pickle.dump(regressor,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("Finalized_model_linear.sav",'rb'))
result=loaded_model.predict([[0]])
# Out:
# C:\Anaconda 3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[18757.923448]])
